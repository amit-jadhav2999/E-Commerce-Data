# %%
# Import Libraries 

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Import File 

df = pd.read_csv("data.csv",encoding="latin-1")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Check row and columns
df.shape
# Out:
# (541909, 8)

# %%
# Columns name 

df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#to show the top data

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Rondum data show

df.sample(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 425724    573336    84997C      CHILDRENS CUTLERY POLKADOT BLUE         3
# 143189    548666     21981         PACK OF 12 WOODLAND TISSUES         12
# 369328    569026     21928  JUMBO BAG SCANDINAVIAN BLUE PAISLEY        10
# 85899     543530     22839      3 TIER CAKE TIN GREEN AND CREAM         2
# 476460    577020     22423             REGENCY CAKESTAND 3 TIER         6
# 109519    545649     21983     PACK OF 12 BLUE PAISLEY TISSUES          1
# 207277    554981     22371         AIRLINE BAG VINTAGE TOKYO 78         4
# 240404    558099     22794        SWEETHEART WIRE MAGAZINE RACK         3
# 501096    578818     23157           SET OF 6 NATIVITY MAGNETS         12
# 157783    550211     22317         FIVE CATS HANGING DECORATION         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 425724  10/30/2011 11:37       4.15     17372.0  United Kingdom
# ...

# %%
# To show to record 
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
# To show the data as per req

df.iloc[25:50]
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 25    536369     21756             BATH BUILDING BLOCK WORD         3
# 26    536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727            ALARM CLOCK BAKELIKE RED         24
# 28    536370     22726           ALARM CLOCK BAKELIKE GREEN        12
# 29    536370     21724      PANDA AND BUNNIES STICKER SHEET        12
# 30    536370     21883                     STARS GIFT TAPE         24
# 31    536370     10002          INFLATABLE POLITICAL GLOBE         48
# 32    536370     21791   VINTAGE HEADS AND TAILS CARD GAME         24
# 33    536370     21035      SET/2 RED RETROSPOT TEA TOWELS         18
# 34    536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND         24
# 35    536370     22629                  SPACEBOY LUNCH BOX         24
# 36    536370     22659              LUNCH BOX I LOVE LONDON        24
# ...

# %%
# file information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# to show the Fill data count 

df.count()
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %%
# To show the more information about data

df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# To show the data type

df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df["InvoiceDate"]= pd.to_datetime(df["InvoiceDate"])

# %%
# To show the how many invoice no are present 

df["InvoiceNo"].unique().size
# Out:
# 25900

# %%
# totat type of material

df["StockCode"].unique().size
# Out:
# 4070

# %%
# to show the how many cuntry and customer are available 

print("Number Of customer is : ",df["CustomerID"].unique().size)
print("Number of city to connected company : ",df["Country"].unique().size)
# Out:
# Number Of customer is :  4373
# Number of city to connected company :  38

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df["Country"].nunique()
# Out:
# 38

# %%
# To Show the unique data as per columns

df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
df["Country"].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
# to show the data custry is Australia and France

df[(df.Country =="Australia") | (df.Country =="France") ]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# ...

# %%
# To show the data is qty less than 2 or price less than 2 

df[(df.Quantity <2 )& (df.UnitPrice <2)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 113       536381     71270                   PHOTO CLIP LINE         1
# 114       536381     22262             FELT EGG COSY CHICKEN         1
# 118       536381     21166        COOK WITH WINE METAL SIGN          1
# 127       536381     22261       FELT EGG COSY WHITE RABBIT          1
# 128       536381     84832  ZINC WILLIE WINKIE  CANDLE STICK         1
# ...          ...       ...                               ...       ...
# 541842    581580     20974       12 PENCILS SMALL TUBE SKULL         1
# 541844    581580    85049A     TRADITIONAL CHRISTMAS RIBBONS         1
# 541846    581580     22695               WICKER WREATH SMALL         1
# 541851    581580     22721     SET OF 3 CAKE TINS SKETCHBOOK         1
# 541857    581580     22567           20 DOLLY PEGS RETROSPOT         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# To display the top 150 record in USA in less than 2 both qty or price

df[(df.Country == "USA")& (df.Quantity <2)& (df.UnitPrice <2)]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 164468    550644     22993    SET OF 4 PANTRY JELLY MOULDS         1
# 393995   C570867     23290         SPACEBOY CHILDRENS BOWL        -8
# 393996   C570867     23289       DOLLY GIRL CHILDRENS BOWL        -8
# 394001   C570867     23167  SMALL CERAMIC TOP STORAGE JAR        -12
# 394002   C570867     23166  MEDIUM CERAMIC TOP STORAGE JAR       -12
# ...          ...       ...                             ...       ...
# 536921   C581229     23209        LUNCH BAG VINTAGE DOILY        -20
# 536923   C581229     22712                CARD DOLLY GIRL        -12
# 536924   C581229     22027         TEA PARTY BIRTHDAY CARD       -12
# 536925   C581229     21508         VINTAGE KID DOLLY CARD        -12
# 536926   C581229     21507         ELEPHANT BIRTHDAY CARD        -12
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 164468 2011-04-19 16:19:00       1.25     12733.0     USA
# ...

# %%
df["Country"].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
# To the total sales 

# Note in data missing total value of invoice to add new column is total value

df["TotalValue"]= df["Quantity"] * df["UnitPrice"]
df

# Total invoice pricing is 

print("Total Invoice value is : ", df["TotalValue"].sum().round(2))
# Out:
# Total Invoice value is :  9747747.93

# %%
# To find the Stock code price 
df.groupby("StockCode")["UnitPrice"].min()
# Out:
# StockCode
# 10002            0.00
# 10080            0.00
# 10120            0.21
# 10123C           0.00
# 10123G           0.00
#                 ...
# gift_0001_20     0.00
# gift_0001_30     0.00
# gift_0001_40    33.33
# gift_0001_50    41.67
# m                2.55
# Name: UnitPrice, Length: 4070, dtype: float64

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'TotalValue'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'TotalValue'],
#       dtype='object')

# %%
import pandas as pd

# Create a DataFrame with missing values
data = {'A': [1, 2, None, 4, None],
        'B': [None, 5, None, None, 8]}
df1 = pd.DataFrame(data)

# Forward fill missing values
df_filled = df1.ffill()

print("Original DataFrame:")
print(df1)
print("\nDataFrame after forward fill:")
print(df_filled)
